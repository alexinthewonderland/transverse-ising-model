# %% [markdown]
# # 1. Importing the Libraries

# %%
import qutip
import numpy as np
from qutip import *
import matplotlib.pyplot as plt
from scipy.fft import *
import numpy.linalg as nplin
from mpl_toolkits import mplot3d

# %% [markdown]
# # 2.  Building the Functions

# %% [markdown]
# ## a. The coefficients for the time-periodical Hamiltonian operator

# %%
def coef_z(t, args):
    c_coeff_arr = args['c_coeff']
    omega = args['omega']
    N_max = args['Nmax']
    tsize = args['tsize']
    qJ = args['qJ']
    freq = args['freq']
    
    c_result = np.sum(c_coeff_arr*np.exp((2*np.pi*1j*freq*t)))*1/tsize
        
    return qJ*c_result
  
    
def coef_x(t, args): # This is the oscillating field term
    
    omega = args['omega'] 
    Bx = args['Bx']

    return Bx*np.cos(omega*t)

# %% [markdown]
# ## b. Finding the magnetization expectation values for each direction (x, y, and z)

# %%
def mz_expect(f_modes_table_t, tlist):
    mz_time = []
    for i in range(len(tlist)):
        a = f_modes_table_t[i][0][0]
        b = f_modes_table_t[i][0][1]
        mz_temp = (a.conj()*a-b.conj()*b)[0][0].real
        mz_time.append(mz_temp)
        
    return mz_time


def mx_expect(f_modes_table_t, tlist):
    mx_time = []
    for i in range(len(tlist)):
        a = f_modes_table_t[i][0][0]
        b = f_modes_table_t[i][0][1]
        mx_temp = (a.conj()*b+b.conj()*a)[0][0].real
        mx_time.append(mx_temp)
        
    return mx_time


def my_expect(f_modes_table_t, tlist):
    my_time = []
    for i in range(len(tlist)):
        a = f_modes_table_t[i][0][0]
        b = f_modes_table_t[i][0][1]
        my_temp = (a.conj()*-1j*b+b.conj()*1j*a)[0][0].real
        my_time.append(my_temp)
        
    return my_time


def energy_expect(f_modes_table_t, mz_expect, qJ, omega, Bx, tlist):
    
    energy_time=[]
    for i in range(len(tlist)):
        hamiltonian_matrix = np.array([[qJ*mz_expect[i], Bx*np.cos(omega*tlist[i])],
                                       [Bx*np.cos(omega*tlist[i]), -qJ*mz_expect[i]]])
        
        a = f_modes_table_t[i][0][0] 
        b = f_modes_table_t[i][0][1]
        vector = np.array([a[0][0], b[0][0]])
        first_mul = hamiltonian_matrix @ vector
        second_mul = np.matmul(np.conjugate(vector),first_mul)
        energy_time.append(second_mul)
    
    return energy_time

# %% [markdown]
# ## c. Constructing the initial guess of the z-axis magnetization DFT coefficient

# %%
def mz_time(c_coeff, time, N_max, omega):

  mz_arr = []

  c_coeff = c_coeff.flatten(order='C')

  for t in time:
    result = 0
    for i in range(len(c_coeff)):
        
      result += c_coeff[i]*np.exp(complex(0, omega*(N_max-i)*t))
 
    mz_arr.append(result)

  return mz_arr


    

def create_cdft_init(N_max, omega, tlist): # Creating the initial DFT coefficient guess
    
    col_size = 2*(2*N_max + 1)

    c_array_init = np.zeros((1,int(col_size/2)),dtype=np.complex_)
    count = 2
    
    for i in range(int(col_size/2)):

        if(i == N_max):
            c_array_init[0,i] = 1
        elif(i > N_max):
            c_array_init[0,i] = 0
            count += 2
        else:
            c_array_init[0,i] = 0

            
    temp = mz_time(c_array_init, tlist, N_max, omega)
    #plt.plot(tlist, temp)
    
    #cdft_init = fft(np.sin(omega*tlist+(0.5)))
    cdft_init = fft(temp)
    return cdft_init

# %% [markdown]
# ## d. Checking whether the numerical iteration meets the converging condition or not

# %%
def check_c_same(c_coeff_prev, c_coeff_now, tol=1e-4): # This is to check if the prev and present c_coeff is the same or not
    return np.all(np.abs(c_coeff_now - c_coeff_prev) < tol)


def check_quasi_same(quasi_prev, quasi_now, tol=1e-6):
    if(np.abs(quasi_now-quasi_prev)<1e-6):
        return True
    else:
        return False
    
    
def check_mz_time_same(mz_prev, mz_now, tol=1e-4):
    
    return np.all(np.abs(np.array(mz_now) - np.array(mz_prev))<tol)

# %% [markdown]
# # 3. Fixed Point Iteration using QuTiP

# %%
## Some Variables ## 
N_max = 60

total_mz_arr = []
total_mx_arr = []
total_my_arr = []
total_energy_arr = []

c_coeff_arr = []

mz_time_arr = []
mx_time_arr = []
my_time_arr = []


omega_arr = [4]
h_bar = 1 # Here, we set the planck constant to be 1
qJ = 2


H0 = 2 * np.pi * 0 * sigmaz()
Hx = sigmax() # The Pauli matrix for the spin in the x direction
Hz = sigmaz() # The Pauli matrix for the spin in the z direction
 


for omega in omega_arr: # Looping through different omegas
    
    print("The current omega value:", omega)
    
    ## Some empty arrays ##
    mz_avg_arr = [] # Storing the average expectation value of Mz of different omegas
    mx_avg_arr = [] # Storing the average expectation value of Mx of different omegas
    my_avg_arr = [] # Storing the average expectation value of My of different omegas
    energy_avg_arr = [] # Storing the average expectation value of the Hamiltonian of different omegas
    
    ## Important variables ##
    T = 2*np.pi/omega # The period of the oscillating field
    tstep = 0.01  # The stepping between each point in time
    tlist = np.arange(0, T, tstep)
    tsize = tlist.size # The size of tlist array
    N_max = 60 # The number of DFT/FFT coefficient present
    freq = np.fft.fftfreq(tsize, d=tstep) # the DFT sample frequencies
    
    ## Initializing the initial guess ## 
    c_array_init = create_cdft_init(N_max, omega, tlist) # Calling the initial guess function
    c_coeff_prev = c_array_init # A local variable inside the for loop ??
    

    Bx_arr = np.arange(3, 3.1, 0.1) # The Bx that we are going to use
    

    for Bx in Bx_arr: # Looping through different Bx values
        
        counter = 0 # Counting the number of times the iteration has passed (max is 10000) 
        
        ## The initial status of the converging conditions ##
        condition_c_coeff = False 
        condition_quasi = False 
        condition_mz_time = False
        
        ## Setting the initial values for different variables ##
        c_coeff_now = c_coeff_prev
        c_coeff_arr.append(c_coeff_now)
        quasi_now = 0
        mz_prev = -999 # Just setting some random large values for the previous Mz
        mz_now = 999
        mx_now = None 
        my_now = None

        
        
        while( (((condition_quasi == False) or (condition_mz_time == False)) and counter < 10000)):

            # Saving to the previous one
            quasi_prev = quasi_now 
            
            # Building the new Hamiltonian
            args={'c_coeff':c_coeff_prev,'omega':omega, 'Nmax':N_max, 'qJ': qJ, 'Bx':Bx, 'tsize':tsize, 'freq': freq}
            H=[H0,[Hx, coef_x], [Hz, coef_z]]
            
            # f_modes_0: The floquet modes at t = 0
            # f_energies: The quasienergies at t = 0
            f_modes_0, f_energies = floquet_modes(H, T, args, sort = True, options=Options(nsteps=1000))
            quasi_now = f_energies[0] # Only taking the positive version of the quasienergies
            
            # Generating the other floquet modes for other time t 
            f_modes_table_t = floquet_modes_table(f_modes_0, f_energies, tlist, H, T, args) 
            
            
            ## Finding the expectation values for Mz, Mx, and My ##
            mz_now = mz_expect(f_modes_table_t, tlist)
            mx_now = mx_expect(f_modes_table_t, tlist)
            my_now = my_expect(f_modes_table_t, tlist)
            c_coeff_now = fft(mz_now)
            
            ## Updating the convergence condition ##
            condition_mz_time = check_mz_time_same(mz_prev, mz_now)
            condition_c_coeff =  check_c_same(c_coeff_prev, c_coeff_now)
            condition_quasi = check_quasi_same(quasi_prev, quasi_now)
            
            
            ## Updating some variables ## 
            c_coeff_prev = c_coeff_now*0.6+ c_coeff_prev*(0.4) # Using the Sucessive Under/Over Method
            mz_prev = mz_now
            mx_prev = mx_now
            my_prev = my_now
            counter += 1 # Increasing the number of iteration

            
        
        
        print("Bx:", Bx, "has found its solution!") 


        ## Appending the time evolution of the magnetization of a certain Bx to an array ##
        mz_time_arr.append(mz_now)
        mx_time_arr.append(mx_now)
        my_time_arr.append(my_now)
        
        ## Finding the average values ##
        mz_avg = np.absolute(np.average(mz_now))
        mz_avg_arr.append(mz_avg)
        
        mx_avg = np.absolute(np.average(mx_now))
        mx_avg_arr.append(mx_avg)
        
        my_avg = np.absolute(np.average(my_now))
        my_avg_arr.append(my_avg)
        
        energy_time_val = energy_expect(f_modes_table_t, mz_now, qJ, omega, Bx, tlist)
        energy_avg = np.absolute(np.average(energy_time_val))
        energy_avg_arr.append(energy_avg)
        
              


    total_mz_arr.append(mz_avg_arr)
    total_mx_arr.append(mx_avg_arr)
    total_my_arr.append(my_avg_arr)
    total_energy_arr.append(energy_avg_arr)
# Out:
# The current omega value: 4
# Bx: 3.0 has found its solution!
# Bx: 3.1 has found its solution!

# %% [markdown]
# # 4. Plot the results

# %% [markdown]
# ## a. Average magnetization vs Bx (with the same ω)

# %%
plt.cla()
plt.plot(Bx_arr, total_mz_arr[0])
plt.plot(Bx_arr, total_mx_arr[0])
plt.plot(Bx_arr, total_my_arr[0])
plt.grid()
plt.xlabel("Bx")
plt.ylabel("Mz, Mx, and My Average")
plt.show()

# %% [markdown]
# ## b. Magnetization (Mz(t), Mx(t), My(t) vs Time (t))

# %%
fig, (ax_x, ax_y, ax_z) = plt.subplots(nrows=3, ncols=1, figsize=(8, 20))

## The plot for Mx(t) vs Time t ##
ax_x.plot(tlist, mx_time_arr[0])
ax_x.set_title('Expectation value of x-axis magnetization (Mx) vs Time')
ax_x.set_xlabel("Time t")
ax_x.set_ylabel("Mx(t)")
ax_x.grid()

## The plot for My(t) vs Time t ##
ax_y.plot(tlist, my_time_arr[0], color = 'orange')
ax_y.set_title('Expectation value of y-axis magnetization (My) vs Time')
ax_y.set_xlabel("Time t")
ax_y.set_ylabel("My(t)")
ax_y.grid()

## The plot for Mz(t) vs Time t ##
ax_z.plot(tlist, mz_time_arr[0], color='green')
ax_z.set_title('Expectation value of z-axis magnetization (Mz) vs Time')
ax_z.set_xlabel("Time t")
ax_z.set_ylabel("Mz(t)")
ax_z.grid()

# %% [markdown]
# ## c. Plotting the total magnitude expectation value of the magnetization as a function of time (checking whether it is normalized or not)

# %%
idx = np.where(Bx_arr == 3)
total_m = np.square(mx_time_arr[idx[0][0]])+np.square(my_time_arr[idx[0][0]])+np.square(mz_time_arr[idx[0][0]])
plt.ylim(-1.1, 1.1)
plt.xlabel("Time")
plt.ylabel("Magnetization Amplitude")
plt.grid()
plt.plot(tlist, total_m)

# %% [markdown]
# ## d. Magnetization Squared vs Bx

# %%
plt.plot()

# %% [markdown]
# # 5. 3D Projection and Bloch sphere visualization

# %% [markdown]
# ## a. Functions needed for the projection

# %%
## Rotational matrices as functions ##
def z_axis_rot(angle, vector):
    rot_matrix = np.array([[np.cos(angle), -np.sin(angle), 0],
                           [np.sin(angle), np.cos(angle), 0],
                           [0, 0, 1]])
    
    new_vector = np.matmul(rot_matrix, vector)
    
    return new_vector;


def x_axis_rot(angle, vector):
    rot_matrix = np.array([[np.cos(angle), 0, np.sin(angle)],
                           [0, 1, 0],
                           [-np.sin(angle), 0, np.cos(angle)]])
    
    new_vector = np.matmul(rot_matrix, vector)
    
    return new_vector;
    
def y_axis_rot(angle, vector):
    rot_matrix = np.array([[1, 0, 0], 
                           [0, np.cos(angle), -np.sin(angle)], 
                           [0, np.sin(angle), np.cos(angle)]])
    
    new_vector = np.matmul(rot_matrix, vector)
    
    return new_vector;


## Indicating which quadrant is the magnetization vector is on (in 2D space) ##
def which_quadrant(x,y):
    quadrant = 0
    if(x>0 and y>0):
        quadrant = 1
        return int(quadrant)
    elif(x<0 and y>0):
        quadrant = 2
        return int(quadrant)
    elif(x<0 and y<0):
        quadrant = 3
        return int(quadrant)
    elif(x>0 and y<0):
        quadrant = 4
        return int(quadrant)

# %% [markdown]
# ## b. The magnetization vector in the form of (Mz, Mx, My) and their spherical coordinates

# %%
## Projection of the average Mx, My, Mz to a spherical coordinate ##
idx = np.where(Bx_arr == 3) # Give the index of a specific Bx value (in this case is Bx = 3.1)

p_radius = np.sqrt(np.square(total_mx_arr[0][idx[0][0]])+np.square(total_my_arr[0][idx[0][0]])
                   +np.square(total_mz_arr[0][idx[0][0]]))

p_theta = np.arctan(total_my_arr[0][idx[0][0]]/total_mx_arr[0][idx[0][0]])  # z-axis rotation

p_phi = np.arctan(np.sqrt(np.square(total_mx_arr[0][idx[0][0]])+np.square(total_my_arr[0][idx[0][0]]))
                  /total_mz_arr[0][idx[0][0]]) 

## Constructing the magnetization vector ##
M_array = []
for i in range(np.shape(mz_time_arr[idx[0][0]])[0]):
    M_vector = []
    M_vector.append((mx_time_arr[idx[0][0]])[i])
    M_vector.append((my_time_arr[idx[0][0]])[i])
    M_vector.append((mz_time_arr[idx[0][0]])[i])
    M_array.append(M_vector)

# %% [markdown]
# ## c. Plotting the magnetization time-evolution on a Bloch sphere (3D Plot)

# %%
# %matplotlib
plt.cla()
origin_point = [0,0,0]
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

r = 0.05
u, v = np.mgrid[0:2 * np.pi:30j, 0:np.pi:20j]
x = np.cos(u) * np.sin(v)
y = np.sin(u) * np.sin(v)
z = np.cos(v)
ax.plot_surface(x, y, z, cmap=plt.cm.YlGnBu_r, alpha=0.5)
plt.xlabel("Mx")
plt.ylabel("My")
ax.set_zlabel("Mz")

for i in range(np.shape(mz_time_arr[idx[0][0]])[0]): 

    ax.set_ylim(-1,1)
    ax.set_zlim(-1,1)
    ax.set_xlim(-1,1)
    ax.grid()
    ax.scatter3D(M_array[i][0], M_array[i][1],M_array[i][2], color = "green", s=0.5)
    
    plt.show()
# Out:
# Using matplotlib backend: MacOSX

# %% [markdown]
# ## d. 2D Plotting (Stereographic Projection) and The Winding Number

# %%
# %matplotlib

theta = np.linspace( 0 , 2 * np.pi , 150 )
radius = 10
 
    
a = radius * np.cos( theta )
b = radius * np.sin( theta )

a = 2*radius*a/(radius-0)
b = 2*radius*b/(radius-0)

 
figure_2d, axes_2d = plt.subplots( 1 )
 
axes_2d.cla()

plt.xlim(-1,1)
plt.ylim(-3,3)

plt.xlabel("Y")
plt.ylabel("Z")

prev_proj_theta = 0;
proj_theta_sum = 0;
proj_theta_arr = []
proj_rad_arr = []

angle_z = 0
angle_x = 0
angle_y = p_phi

X_arr = []
Y_arr = []

present_quadrant = 0
prev_quadrant = 0

q4_to_q1 = 0 # when q4_to_q1 = 1, it inidicates that the vector is going from quadrant 4 to quadrant 1



for i in range(np.shape(mz_time_val)[0]):
    new_vector = z_axis_rot(angle_z, M_array[i])
    new_vector = x_axis_rot(angle_x, new_vector)
    new_vector = y_axis_rot(angle_y, new_vector)

    x = new_vector[0]
    y = new_vector[1]
    z = new_vector[2]
    
    
    X = 2*radius*x/(radius-z)
    Y = 2*radius*y/(radius-z)
    
    
    X_arr.append(X)
    Y_arr.append(Y)
    

grad_X = np.gradient(X_arr)
grad_Y = np.gradient(Y_arr)
int_result = 0 


for i in range(np.shape(mz_time_val)[0]):
    
    proj_theta = np.degrees(np.arctan(Y_arr[i]/X_arr[i]))
    proj_rad = np.sqrt(X_arr[i]**2+Y_arr[i]**2)
    
    present_quadrant = which_quadrant(X_arr[i], Y_arr[i])
    
    if(present_quadrant != prev_quadrant):
        if(present_quadrant == 1 and prev_quadrant == 4):
            q4_to_q1 += 1
        elif(present_quadrant == 4 and prev_quadrant == 1):
            q4_to_q1 -= 1
        
    if(q4_to_q1 != 0):
        proj_theta = (q4_to_q1*360)+proj_theta
        
    if(Y_arr[i] > 0 and X_arr[i]<0):
        proj_theta = 180+proj_theta
        
    elif(Y_arr[i]<0 and X_arr[i]<0):
        proj_theta = 180+proj_theta
        
    elif(Y_arr[i]<0 and X_arr[i]>0):
        proj_theta = 360+proj_theta
        
    proj_theta_arr.append(proj_theta)
    proj_rad_arr.append(proj_rad)
    
    
    
    if(i==0):
        proj_theta_diff = 0
    else:
        proj_theta_diff = (proj_theta-prev_proj_theta)
        
        
    proj_theta_sum += proj_theta_diff
    print("this is number of windings per time:", proj_theta_sum/360, "This is the theta:",proj_theta)
    print("This is the difference:",proj_theta_diff)
    print()

    prev_proj_theta = proj_theta
    prev_quadrant = present_quadrant
    

    axes_2d.scatter(0,0,color="blue",s=0.5)
    axes_2d.scatter(X_arr[i],Y_arr[i], color = "green", s=0.5)
    #plt.pause(1)
    
    
    plt.show()
    
n_of_windings = proj_theta_sum/(360)
print(n_of_windings)
# Out:
# Using matplotlib backend: MacOSX
# this is number of windings per time: 0.0 This is the theta: 179.16465914330857
# This is the difference: 0
#
# this is number of windings per time: 0.16858184918649247 This is the theta: 239.85412485044586
# This is the difference: 60.68946570713729
#
# this is number of windings per time: 0.20204444232692798 This is the theta: 251.90065838100264
# This is the difference: 12.046533530556786
#
# this is number of windings per time: 0.2124057526840478 This is the theta: 255.63073010956577
# This is the difference: 3.730071728563132
#
# this is number of windings per time: 0.21628882242251682 This is the theta: 257.0286352154146
# This is the difference: 1.3979051058488494
#
# this is number of windings per time: 0.2178497916287868 This is the theta: 257.5905841296718
# This is the difference: 0.5619489142571865
#
# this is number of windings per time: 0.2183887773454121 This is the theta: 257.7846189876569
# This is the difference: 0.1940348579851161
#
# this is number of windings per time: 0.21844942401925926 This is the theta: 257.8064517902419
# This is the difference: 0.021832802584981437
#
# this is number of windings per time: 0.21811772163082652 This is the theta: 257.6870389304061
# This is the difference: -0.11941285983579064
#
# this is number of windings per time: 0.217133471061402 This is the theta: 257.3327087254133
# This is the difference: -0.3543302049928343
#
# this is number of windings per time: 0.2147802966081963 This is the theta: 256.48556592225924
# This is the difference: -0.8471428031540427
#
# this is number of windings per time: 0.20915649749211546 This is the theta: 254.46099824047013
# This is the difference: -2.024567681789108
#
# this is number of windings per time: 0.19471292458649342 This is the theta: 249.2613119944462
# This is the difference: -5.19968624602393
#
# this is number of windings per time: 0.1459443011623396 This is the theta: 231.70460756175083
# This is the difference: -17.55670443269537
#
# this is number of windings per time: -0.049572980915296466 This is the theta: 161.31838601380184
# This is the difference: -70.38622154794899
#
# this is number of windings per time: -0.16809377352936153 This is the theta: 118.65090067273842
# This is the difference: -42.667485341063426
#
# this is number of windings per time: -0.1956374470815587 This is the theta: 108.73517819394743
# This is the difference: -9.915722478790983
#
# this is number of windings per time: -0.20502396052170707 This is the theta: 105.35603335549402
# This is the difference: -3.3791448384534135
#
# this is number of windings per time: -0.20878060769753318 This is the theta: 104.00364037219663
# This is the difference: -1.352392983297392
#
# this is number of windings per time: -0.21024851009323933 This is the theta: 103.4751955097424
# This is the difference: -0.5284448624542222
#
# this is number of windings per time: -0.2107331510838673 This is the theta: 103.30072475311634
# This is the difference: -0.17447075662606437
#
# this is number of windings per time: -0.2108022099069881 This is the theta: 103.27586357679286
# This is the difference: -0.02486117632348339
#
# this is number of windings per time: -0.210764487748641 This is the theta: 103.28944355379781
# This is the difference: 0.013579977004951616
#
# this is number of windings per time: -0.21077108644994394 This is the theta: 103.28706802132875
# This is the difference: -0.002375532469059749
#
# this is number of windings per time: -0.2109070867451529 This is the theta: 103.23810791505352
# This is the difference: -0.048960106275231396
#
# this is number of windings per time: -0.21121176550963275 This is the theta: 103.12842355984078
# This is the difference: -0.10968435521273534
#
# this is number of windings per time: -0.21169586581944244 This is the theta: 102.95414744830929
# This is the difference: -0.1742761115314977
#
# this is number of windings per time: -0.21236580990255216 This is the theta: 102.7129675783898
# This is the difference: -0.2411798699194918
#
# this is number of windings per time: -0.21320968526076906 This is the theta: 102.40917244943171
# This is the difference: -0.303795128958086
#
# this is number of windings per time: -0.21423684868830242 This is the theta: 102.0393936155197
# This is the difference: -0.36977883391200805
#
# this is number of windings per time: -0.2154429315964191 This is the theta: 101.60520376859769
# This is the difference: -0.4341898469220098
#
# this is number of windings per time: -0.21686833302639835 This is the theta: 101.09205925380516
# This is the difference: -0.5131445147925291
#
# this is number of windings per time: -0.21854441348544007 This is the theta: 100.48867028855014
# This is the difference: -0.6033889652550215
#
# this is number of windings per time: -0.22057229998785105 This is the theta: 99.7586311476822
# This is the difference: -0.7300391408679445
#
# this is number of windings per time: -0.22304333785956573 This is the theta: 98.8690575138649
# This is the difference: -0.8895736338172924
#
# this is number of windings per time: -0.22612805429605537 This is the theta: 97.75855959672863
# This is the difference: -1.1104979171362714
#
# this is number of windings per time: -0.22994038502943523 This is the theta: 96.38612053271189
# This is the difference: -1.3724390640167456
#
# this is number of windings per time: -0.23460359338625578 This is the theta: 94.70736552425649
# This is the difference: -1.678755008455397
#
# this is number of windings per time: -0.2400332841217693 This is the theta: 92.75267685947162
# This is the difference: -1.954688664784868
#
# this is number of windings per time: -0.2460271941625944 This is the theta: 90.59486924477459
# This is the difference: -2.1578076146970346
#
# this is number of windings per time: -0.2521266167109977 This is the theta: 88.39907712734941
# This is the difference: -2.195792117425171
#
# this is number of windings per time: -0.25791362384451916 This is the theta: 86.31575455928167
# This is the difference: -2.083322568067743
#
# this is number of windings per time: -0.26299969526634176 This is the theta: 84.48476884742554
# This is the difference: -1.8309857118561297
#
# this is number of windings per time: -0.26727502038791423 This is the theta: 82.94565180365944
# This is the difference: -1.5391170437660975
#
# this is number of windings per time: -0.2707299560847715 This is the theta: 81.70187495279082
# This is the difference: -1.2437768508686275
#
# this is number of windings per time: -0.27351943141885493 This is the theta: 80.69766383252079
# This is the difference: -1.0042111202700283
#
# this is number of windings per time: -0.27576553571299356 This is the theta: 79.8890662866309
# This is the difference: -0.8085975458898957
#
# this is number of windings per time: -0.27762355113008813 This is the theta: 79.22018073647683
# This is the difference: -0.6688855501540587
#
# this is number of windings per time: -0.2791731743919699 This is the theta: 78.66231636219939
# This is the difference: -0.5578643742774432
#
# this is number of windings per time: -0.28049603039519394 This is the theta: 78.18608820103874
# This is the difference: -0.47622816116064826
#
# this is number of windings per time: -0.28161573420152164 This is the theta: 77.78299483076077
# This is the difference: -0.403093370277972
#
# this is number of windings per time: -0.2825601046758109 This is the theta: 77.44302146001665
# This is the difference: -0.3399733707441186
#
# this is number of windings per time: -0.28332302744472254 This is the theta: 77.16836926320845
# This is the difference: -0.27465219680820496
#
# this is number of windings per time: -0.2839089670119793 This is the theta: 76.957431018996
# This is the difference: -0.21093824421244278
#
# this is number of windings per time: -0.2843090133223186 This is the theta: 76.81341434727386
# This is the difference: -0.1440166717221416
#
# this is number of windings per time: -0.28453376787129386 This is the theta: 76.73250270964279
# This is the difference: -0.08091163763107545
#
# this is number of windings per time: -0.284602917636783 This is the theta: 76.70760879406667
# This is the difference: -0.024893915576114978
#
# this is number of windings per time: -0.28457551299659717 This is the theta: 76.71747446453358
# This is the difference: 0.009865670466908227
#
# this is number of windings per time: -0.28456100504829634 This is the theta: 76.72269732592189
# This is the difference: 0.005222861388304523
#
# this is number of windings per time: -0.284771816771884 This is the theta: 76.64680510543032
# This is the difference: -0.07589222049156774
#
# this is number of windings per time: -0.2856096307747692 This is the theta: 76.34519206439167
# This is the difference: -0.3016130410386495
#
# this is number of windings per time: -0.287899189882824 This is the theta: 75.52095078549193
# This is the difference: -0.8242412788997342
#
# this is number of windings per time: -0.2935815449616477 This is the theta: 73.4753029571154
# This is the difference: -2.0456478283765307
#
# this is number of windings per time: -0.3084992007548456 This is the theta: 68.10494687156415
# This is the difference: -5.370356085551251
#
# this is number of windings per time: -0.35963144443215694 This is the theta: 49.697339147732066
# This is the difference: -18.407607723832086
#
# this is number of windings per time: -0.5594311297818165 This is the theta: -22.230547578145377
# This is the difference: -71.92788672587744
#
# this is number of windings per time: -0.6720764588672954 This is the theta: -62.782866048917754
# This is the difference: -40.55231847077238
#
# this is number of windings per time: -0.698538600585776 This is the theta: -72.30923706757079
# This is the difference: -9.526371018653037
#
# this is number of windings per time: -0.7077158636478663 This is the theta: -75.61305176992329
# This is the difference: -3.303814702352497
#
# this is number of windings per time: -0.7114726385122035 This is the theta: -76.96549072108468
# This is the difference: -1.352438951161389
#
# this is number of windings per time: -0.7130580973258897 This is the theta: -77.53625589401167
# This is the difference: -0.5707651729269969
#
# this is number of windings per time: -0.7136851208991404 This is the theta: -77.76198438038193
# This is the difference: -0.225728486370258
#
# this is number of windings per time: -0.7138280197346154 This is the theta: -77.81342796115297
# This is the difference: -0.05144358077103561
#
# this is number of windings per time: -0.7135777122587432 This is the theta: -77.72331726983896
# This is the difference: 0.09011069131400973
#
# this is number of windings per time: -0.7126699069653106 This is the theta: -77.39650736420322
# This is the difference: 0.3268099056357414
#
# this is number of windings per time: -0.7102922592300613 This is the theta: -76.54055417951349
# This is the difference: 0.8559531846897244
#
# this is number of windings per time: -0.7042586712393512 This is the theta: -74.36846250285782
# This is the difference: 2.1720916766556684
#
# this is number of windings per time: -0.6872774093822352 This is the theta: -68.2552082342961
# This is the difference: 6.113254268561718
#
# this is number of windings per time: -0.6186130065085057 This is the theta: -43.53602319975346
# This is the difference: 24.719185034542647
#
# this is number of windings per time: -0.3865174697219888 This is the theta: 40.01837004339262
# This is the difference: 83.55439324314608
#
# this is number of windings per time: -0.3099458611627609 This is the theta: 67.58414912471467
# This is the difference: 27.56577908132205
#
# this is number of windings per time: -0.29166552222764175 This is the theta: 74.16507114135757
# This is the difference: 6.580922016642901
#
# this is number of windings per time: -0.28526169079414804 This is the theta: 76.47045045741531
# This is the difference: 2.3053793160577385
#
# this is number of windings per time: -0.28275107284070083 This is the theta: 77.3742729206563
# This is the difference: 0.903822463240985
#
# this is number of windings per time: -0.28179469502194004 This is the theta: 77.71856893541019
# This is the difference: 0.34429601475389404
#
# this is number of windings per time: -0.281527995992302 This is the theta: 77.81458058607987
# This is the difference: 0.09601165066968065
#
# this is number of windings per time: -0.2816602565493988 This is the theta: 77.76696678552503
# This is the difference: -0.0476138005548421
#
# this is number of windings per time: -0.28226069377430607 This is the theta: 77.5508093845584
# This is the difference: -0.2161574009666225
#
# this is number of windings per time: -0.28377328231406856 This is the theta: 77.0062775102439
# This is the difference: -0.5445318743145009
#
# this is number of windings per time: -0.2873441136852888 This is the theta: 75.72077821660464
# This is the difference: -1.285499293639262
#
# this is number of windings per time: -0.29601022059434356 This is the theta: 72.60097972934491
# This is the difference: -3.119798487259729
#
# this is number of windings per time: -0.32059121885488895 This is the theta: 63.75182035554858
# This is the difference: -8.849159373796333
#
# this is number of windings per time: -0.42297615233616265 This is the theta: 26.893244302290036
# This is the difference: -36.858576053258545
#
# this is number of windings per time: -0.6294967024431545 This is the theta: -47.454153736227
# This is the difference: -74.34739803851704
#
# this is number of windings per time: -0.6854353813508282 This is the theta: -67.59207814298952
# This is the difference: -20.137924406762522
#
# this is number of windings per time: -0.7013285313989791 This is the theta: -73.31361216032388
# This is the difference: -5.721534017334363
#
# this is number of windings per time: -0.7073217395420341 This is the theta: -75.4711670918237
# This is the difference: -2.157554931499817
#
# this is number of windings per time: -0.70973155230916 This is the theta: -76.33869968798899
# This is the difference: -0.8675325961652902
#
# this is number of windings per time: -0.7106153701192304 This is the theta: -76.65687409961436
# This is the difference: -0.318174411625364
#
# this is number of windings per time: -0.7108375723830705 This is the theta: -76.73686691459682
# This is the difference: -0.07999281498246091
#
# this is number of windings per time: -0.710816722796456 This is the theta: -76.72936106341558
# This is the difference: 0.007505851181235812
#
# this is number of windings per time: -0.710773502029174 This is the theta: -76.71380158719404
# This is the difference: 0.01555947622154008
#
# this is number of windings per time: -0.7108219552559091 This is the theta: -76.73124474881865
# This is the difference: -0.017443161624612458
#
# this is number of windings per time: -0.7110236430206627 This is the theta: -76.80385234412995
# This is the difference: -0.07260759531129679
#
# this is number of windings per time: -0.7113997303554414 This is the theta: -76.93924378465027
# This is the difference: -0.1353914405203227
#
# this is number of windings per time: -0.7119613463980066 This is the theta: -77.14142555997375
# This is the difference: -0.20218177532348136
#
# this is number of windings per time: -0.7126996329147174 This is the theta: -77.40720870598966
# This is the difference: -0.2657831460159059
#
# this is number of windings per time: -0.7136184102918686 This is the theta: -77.73796856176409
# This is the difference: -0.33075985577443134
#
# this is number of windings per time: -0.7147106363974648 This is the theta: -78.13116995977873
# This is the difference: -0.3932013980146394
#
# this is number of windings per time: -0.716002535090642 This is the theta: -78.59625348932252
# This is the difference: -0.46508352954379006
#
# this is number of windings per time: -0.7175160369021739 This is the theta: -79.14111414147402
# This is the difference: -0.5448606521514989
#
# this is number of windings per time: -0.7193307887361249 This is the theta: -79.79442480169638
# This is the difference: -0.6533106602223597
#
# this is number of windings per time: -0.7215253618632962 This is the theta: -80.58447112747803
# This is the difference: -0.7900463257816455
#
# this is number of windings per time: -0.7242555900915537 This is the theta: -81.56735328965073
# This is the difference: -0.9828821621727002
#
# this is number of windings per time: -0.7276480020805508 This is the theta: -82.78862160568968
# This is the difference: -1.2212683160389588
#
# this is number of windings per time: -0.7318676290315794 This is the theta: -84.30768730806
# This is the difference: -1.5190657023703125
#
# this is number of windings per time: -0.7369200550225309 This is the theta: -86.12656066480253
# This is the difference: -1.8188733567425288
#
# this is number of windings per time: -0.7427113519247707 This is the theta: -88.21142754960886
# This is the difference: -2.084866884806331
#
# this is number of windings per time: -0.748858815191756 This is the theta: -90.42451432572358
# This is the difference: -2.2130867761147215
#
# this is number of windings per time: -0.7549356075508245 This is the theta: -92.6121595749882
# This is the difference: -2.1876452492646195
#
# this is number of windings per time: -0.7604611652930381 This is the theta: -94.60136036218512
# This is the difference: -1.9892007871969213
#
# this is number of windings per time: -0.7652129515946416 This is the theta: -96.31200343076239
# This is the difference: -1.7106430685772693
#
# this is number of windings per time: -0.7690938175831723 This is the theta: -97.70911518663343
# This is the difference: -1.3971117558710375
#
# this is number of windings per time: -0.7722253627127889 This is the theta: -98.8364714332954
# This is the difference: -1.127356246661975
#
# this is number of windings per time: -0.7747245336285068 This is the theta: -99.73617296295384
# This is the difference: -0.8997015296584436
#
# this is number of windings per time: -0.7767677633447777 This is the theta: -100.47173566081136
# This is the difference: -0.7355626978575174
#
# this is number of windings per time: -0.7784510114979477 This is the theta: -101.07770499595256
# This is the difference: -0.6059693351411966
#
# this is number of windings per time: -0.7798796691536697 This is the theta: -101.5920217520125
# This is the difference: -0.5143167560599409
#
# this is number of windings per time: -0.7810873599693361 This is the theta: -102.02679044565241
# This is the difference: -0.43476869363991
#
# this is number of windings per time: -0.7821164522072095 This is the theta: -102.39726365128683
# This is the difference: -0.37047320563442554
# this is number of windings per time: -0.7829630828560702 This is the theta: -102.70205068487667
# This is the difference: -0.3047870335898324
#
# this is number of windings per time: -0.7836371273816701 This is the theta: -102.94470671409266
# This is the difference: -0.24265602921599339
#
# this is number of windings per time: -0.7841260015194939 This is the theta: -103.12070140370918
# This is the difference: -0.1759946896165161
#
# this is number of windings per time: -0.7844353587197953 This is the theta: -103.23206999581771
# This is the difference: -0.11136859210853345
#
# this is number of windings per time: -0.7845737751833551 This is the theta: -103.28189992269927
# This is the difference: -0.049829926881557185
#
# this is number of windings per time: -0.7845776417942956 This is the theta: -103.28329190263781
# This is the difference: -0.0013919799385462284
#
# this is number of windings per time: -0.784526367495845 This is the theta: -103.26483315519562
# This is the difference: 0.018458747442196
#
# this is number of windings per time: -0.7845620265559361 This is the theta: -103.27767041682841
# This is the difference: -0.012837261632796526
#
# this is number of windings per time: -0.7849748023129588 This is the theta: -103.42626968935656
# This is the difference: -0.14859927252814487
#
# this is number of windings per time: -0.7862934838182217 This is the theta: -103.90099503125123
# This is the difference: -0.4747253418946684
#
# this is number of windings per time: -0.7897198123260746 This is the theta: -105.13447329407825
# This is the difference: -1.2334782628270204
#
# this is number of windings per time: -0.7982517862598832 This is the theta: -108.20598391024936
# This is the difference: -3.0715106161711105
#
# this is number of windings per time: -0.8226862508917843 This is the theta: -117.00239117773373
# This is the difference: -8.79640726748437
#
# this is number of windings per time: -0.9243635017889354 This is the theta: -153.60620150070815
# This is the difference: -36.603810322974425
#
# this is number of windings per time: -1.1312458597952875 This is the theta: -228.0838503829949
# This is the difference: -74.47764888228676
#
# this is number of windings per time: -1.1875943840371492 This is the theta: -248.36931911006513
# This is the difference: -20.285468727070224
#
# this is number of windings per time: -1.2036032669881032 This is the theta: -254.13251697240855
# This is the difference: -5.763197862343418
#
# this is number of windings per time: -1.2097433937781352 This is the theta: -256.34296261682005
# This is the difference: -2.210445644411493
#
# this is number of windings per time: -1.2123119733963679 This is the theta: -257.2676512793838
# This is the difference: -0.9246886625637671
#
# this is number of windings per time: -1.2133997491670585 This is the theta: -257.65925055683243
# This is the difference: -0.3915992774486199
#
# this is number of windings per time: -1.2137895360302684 This is the theta: -257.79957382758806
# This is the difference: -0.1403232707556299
#
# this is number of windings per time: -1.2137791105357583 This is the theta: -257.7958206495644
# This is the difference: 0.0037531780236577106
#
# this is number of windings per time: -1.213312775758674 This is the theta: -257.627940129814
# This is the difference: 0.16788051975038343
#
# this is number of windings per time: -1.211898974823411 This is the theta: -257.1189717931194
# This is the difference: 0.508968336694636
#
# this is number of windings per time: -1.2083549360868073 This is the theta: -255.84311784794204
# This is the difference: 1.2758539451773458
#
# this is number of windings per time: -1.1989615403630212 This is the theta: -252.46149538737905
# This is the difference: 3.381622460562994
#
# this is number of windings per time: -1.1696259516475136 This is the theta: -241.9006834497963
# This is the difference: 10.560811937582741
#
# this is number of windings per time: -1.0226069744423107 This is the theta: -188.97385165592328
# This is the difference: 52.92683179387302
#
# -1.0226069744423107

# %%
theta = np.linspace( 0 , 2 * np.pi , 150 )
radius = 1
vector_pos = []
for i in range(len(theta)):
    temp_vector = []
    a_test = radius*np.cos(theta[i])
    b_test = radius*np.sin(theta[i])
    temp_vector.append(0)
    temp_vector.append(a_test)
    temp_vector.append(b_test)
    vector_pos.append(temp_vector)

# %% [markdown]
# ## USING TOTAL CURVATURE

# %%
tang_vect_arr = [] 
for i in range((np.shape(mz_time_val)[0])-1):
    tang_vect = (np.array(M_array[i+1])-np.array(M_array[i]))/tstep
    tang_vect = tang_vect/np.linalg.norm(tang_vect)
    tang_vect_arr.append(tang_vect) # Here we got T = dr/dt (MUST BE NORMALIZED)
    
diff_tang_vect_arr = []
for i in range(len(tang_vect_arr)-1):
    diff_tang_vect = np.array(tang_vect_arr[i+1])-np.array(tang_vect_arr[i])
    diff_tang_vect_arr.append(diff_tang_vect)

    
angle_z = p_theta
angle_x = p_phi
angle_y = 0   
      
X_arr = []
Y_arr = []

radius = 1

for i in range(np.shape(mz_time_val)[0]):
    new_vector = z_axis_rot(angle_z, M_array[i])
    new_vector = x_axis_rot(angle_x, new_vector)
    new_vector = y_axis_rot(angle_y, new_vector)

    x = new_vector[0]
    y = new_vector[1]
    z = new_vector[2]
    
    
    X = 2*radius*x/(radius-z)
    Y = 2*radius*y/(radius-z)
    
    
    X_arr.append(X)
    Y_arr.append(Y)

    
arc_length = []
for i in range(len(mz_time_val)-1):
    diff_X = X_arr[i+1]-X_arr[i]
    diff_Y = Y_arr[i+1]-Y_arr[i]
    arc_length_single = np.sqrt((diff_X**2)+ (diff_Y**2))
    arc_length.append(arc_length)

# %%
result = 0
for i in range(len(diff_tang_vect_arr)):
    kappa = (np.linalg.norm(diff_tang_vect_arr[i]))
    result += kappa
    
print(result)
# Out:
# 32.74312457243268

# %%
result/(2*np.pi)
# Out:
# 5.211230127976362

# %%
## FOR THE CURVATURE ONE BUT PROJECTED ##

theta = np.linspace( 0 , 2 * np.pi , 150 )
radius = 1
 
a = radius * np.cos( theta )
b = radius * np.sin( theta )

a = 2*radius*a/(radius-0)
b = 2*radius*b/(radius-0)



figure_2d, axes_2d = plt.subplots( 1 )

#axes_2d.cla()
#axes_2d.plot( a, b )

#axes_2d.set_aspect( 1 )
# plt.xlim(-3,3)
# plt.ylim(-3,3)

plt.xlabel("Y")
plt.ylabel("Z")

prev_proj_theta = 0;
proj_theta_sum = 0;
proj_theta_arr = []
proj_rad_arr = []

angle_z = p_theta
angle_x = p_phi
angle_y = 0

X_arr = []
Y_arr = []

present_quadrant = 0
prev_quadrant = 0

q4_to_q1 = 0


for i in range(np.shape(mz_time_val)[0]):
    new_vector = z_axis_rot(angle_z, M_array[i])
    new_vector = x_axis_rot(angle_x, new_vector)
    new_vector = y_axis_rot(angle_y, new_vector)

    x = new_vector[0]
    y = new_vector[1]
    z = new_vector[2]
    
    
    X = 2*radius*x/(radius-z)
    Y = 2*radius*y/(radius-z)
    
    
    X_arr.append(X)
    Y_arr.append(Y)


grad_X = np.gradient(X_arr)
grad_Y = np.gradient(Y_arr)
int_result = 0 

tang_vect_arr_2D = [] 

for i in range((np.shape(mz_time_val)[0])-1):
    diff_X = X_arr[i+1]-X_arr[i]
    diff_Y = Y_arr[i+1]-Y_arr[i]
    
    diff_vect = [diff_X, diff_Y];
    
    tang_vect = np.array(diff_vect)/tstep
    tang_vect = tang_vect/np.linalg.norm(tang_vect)
    tang_vect_arr_2D.append(tang_vect) # Here we got T = dr/dt (MUST BE NORMALIZED)
    
        
        
arc_length = []
for i in range(len(mz_time_val)-1):
    diff_X = X_arr[i+1]-X_arr[i]
    diff_Y = Y_arr[i+1]-Y_arr[i]
    arc_length_single = np.sqrt((diff_X**2)+ (diff_Y**2))
    arc_length.append(arc_length_single)
    
avg_arc_length = []
for i in range(len(arc_length)-1):
    avg_arc = (arc_length[i+1]+arc_length[i])/2
    avg_arc_length.append(avg_arc)
    
    
diff_tang_vect_arr_2D = []
for i in range(len(tang_vect_arr_2D)-1):
    diff_tang_vect = (np.array(tang_vect_arr_2D[i+1])-np.array(tang_vect_arr_2D[i]))/avg_arc_length[i]
    diff_tang_vect_arr_2D.append(diff_tang_vect)
    
    
    
result_2D = 0
for i in range(len(diff_tang_vect_arr_2D)):
    kappa = (np.linalg.norm(diff_tang_vect_arr_2D[i]))*arc_length[i]
    result_2D += kappa
    
    

print(result_2D/(2*np.pi)) 


#derivative_theta = np.gradient(np.arctan(Y_arr/X_arr))

# for i in range(np.shape(mz_time_val)[0]):
# #for i in range(len(theta)):

    

# #     angle_z = 0
# #     angle_x = np.pi/2
# #     angle_y = 0
    
# #     new_vector = z_axis_rot(angle_z, M_array[i])
# #     new_vector = x_axis_rot(angle_x, new_vector)p
# #     x = new_vector[0]
# #     y = new_vector[1]
# #     z = new_vector[2]
    
    
# #     X = 2*radius*x/(radius-z)
# #     Y = 2*radius*y/(radius-z)


# #     int_sum_1 = (-Y_arr[i]/(X_arr[i]**2 + Y_arr[i]**2))*grad_X[i]*tstep
# #     int_sum_2 = (X_arr[i]/(X_arr[i]**2 + Y_arr[i]**2))*grad_Y[i]*tstep
# #     int_result = int_result+int_sum_1+int_sum_2

    
# #     int_result += (derivative_theta[i]*tsteps)
    
#     proj_theta = np.degrees(np.arctan(Y_arr[i]/X_arr[i]))
#     proj_rad = np.sqrt(X_arr[i]**2+Y_arr[i]**2)
    
#     present_quadrant = which_quadrant(X_arr[i], Y_arr[i])
    
#     if(present_quadrant != prev_quadrant):
#         if(present_quadrant == 1 and prev_quadrant == 4):
#             q4_to_q1 += 1
#         elif(present_quadrant == 4 and prev_quadrant == 1):
#             q4_to_q1 -= 1
        
    
#     if(q4_to_q1 != 0):
#         proj_theta = (q4_to_q1*360)+proj_theta
        
        
#     if(Y_arr[i] > 0 and X_arr[i]<0):
#         proj_theta = 180+proj_theta
        
#     elif(Y_arr[i]<0 and X_arr[i]<0):
#         proj_theta = 180+proj_theta
        
#     elif(Y_arr[i]<0 and X_arr[i]>0):
#         proj_theta = 360+proj_theta
        
#     proj_theta_arr.append(proj_theta)
#     proj_rad_arr.append(proj_rad)
    
    
    
#     if(i==0):
#         proj_theta_diff = 0
#     else:
#         proj_theta_diff = (proj_theta-prev_proj_theta)
        
        
#     proj_theta_sum += proj_theta_diff
#     print("this is number of windings per time:", proj_theta_sum/360, "This is the theta:",proj_theta)
#     print("This is the difference:",proj_theta_diff)
#     print()
#     #if(proj_theta_sum/360)
#     prev_proj_theta = proj_theta
#     prev_quadrant = present_quadrant
    
    
#     #proj_radius = np.sqrt(X**2+Y**2)
# #     windings_per_time = proj_theta_sum/360;
# #     if(np.absolute(np.abs(windings_per_time) - 1) < 0.0008):
# #         if(windings_per_time<0):
# #             negative_wind+=1;
# #         else:
# #             positive_wind+=1;
    
#     axes_2d.scatter(0,0,color="blue",s=0.5)
#     axes_2d.scatter(X_arr[i],Y_arr[i], color = "green", s=0.5)
#     #plt.pause(0.1)
    
    
#     plt.show()
    
# n_of_windings = proj_theta_sum/(360)
# print(n_of_windings)
# # print(negative_wind)
# # print(positive_wind)
# Out:
# 7.5008762409878535

# %%
## FOR THE CURVATURE ONE BUT PROJECTED (FOR CIRCLE!!) ##

theta = np.linspace( 0 , 2 * np.pi , 150 )
radius = 1
 
a = radius * np.cos( theta )
b = radius * np.sin( theta )

a = 2*radius*a/(radius-0)
b = 2*radius*b/(radius-0)


figure_2d, axes_2d = plt.subplots( 1 )

axes_2d.cla()
axes_2d.plot( a, b )


angle_z = p_theta
angle_x = p_phi
angle_y = 0

X_arr = []
Y_arr = []

present_quadrant = 0
prev_quadrant = 0

q4_to_q1 = 0



tang_vect_arr_2D = [] 
arc_length = []
for i in range(len(theta)-1):
    diff_X = a[i+1]-a[i]
    diff_Y = b[i+1]-b[i]
    
    diff_vect = [diff_X, diff_Y];
    
    tang_vect = np.array(diff_vect)/0.042
    tang_vect = tang_vect/np.linalg.norm(tang_vect)
    tang_vect_arr_2D.append(tang_vect) # Here we got T = dr/dt (MUST BE NORMALIZED)
    
    arc_length_single = np.sqrt((diff_X**2)+ (diff_Y**2))
    arc_length.append(arc_length_single)
    
        
    
    
diff_tang_vect_arr_2D = []
for i in range(len(tang_vect_arr_2D)-1):
    diff_tang_vect = (np.array(tang_vect_arr_2D[i+1])-np.array(tang_vect_arr_2D[i]))/arc_length[i]
    diff_tang_vect_arr_2D.append(diff_tang_vect)
    
  
    
result_2D = 0
for i in range(len(diff_tang_vect_arr_2D)):
    kappa = (np.linalg.norm(diff_tang_vect_arr_2D[i]))*arc_length[i]
    result_2D += kappa
    
    

print(result_2D/(2*np.pi))
# Out:
# 0.9932149967153124
